# %% [markdown]
# <a href="https://colab.research.google.com/github/whdo787/database/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3 as sl
con = sl.connect('my-test.db')

# %% [markdown]
# create 데이터베이스

# %%
with con:
  con.execute("""
              CREATE TABLE USER (
                id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,
                name TEXT,
                age INTEGER
              );
              """)

# %% [markdown]
# create 테이블, not null자동 증가

# %%
sql = 'insert into user (id, name, age) values(?,?,?)'
data = [ (1, 'Alice', 21),
        (2, 'bob', 22),
        (3, 'chris', 23)]

# %%
with con:
  con.executemany(sql, data)

# %% [markdown]
# 데이타 *자동입력*/ 비쥬얼라이즈

# %%
with con : 
  data = con.execute("select * from user where age <=22")
  for row in data:
    print(row)
# Out:
# (1, 'Alice', 21)
# (2, 'bob', 22)

# %%
import pandas as pd
df_skill = pd.DataFrame({
    'user_id' : [1,1,2,2,3,3,3],
    'skill' : ['Network Security', 'Algorithm Development', 'Network Security', 'Java', 'Python', 'Data Science','Machine Learning' ]
})
df_skill
# Out:
#    user_id                  skill
# 0        1       Network Security
# 1        1  Algorithm Development
# 2        2       Network Security
# 3        2                   Java
# 4        3                 Python
# 5        3           Data Science
# 6        3       Machine Learning

# %%
df_skill.to_sql('SKILL', con)
df = pd.read_sql('''
SELECT s.user_id, u.name, u.age, s.skill
FROM USER u LEFT JOIN SKILL s ON u.id=s.user_id''', con)
df
# Out:
#    user_id   name  age                  skill
# 0        1  Alice   21  Algorithm Development
# 1        1  Alice   21       Network Security
# 2        2    bob   22                   Java
# 3        2    bob   22       Network Security
# 4        3  chris   23           Data Science
# 5        3  chris   23       Machine Learning
# 6        3  chris   23                 Python

# %%
df_skill.to_sql('USER_SKILL', con)

# %%
# %load_ext sql
from random import uniform, choice
import time
from datetime import datetime, timedelta
import pandas as pd
# %matplotlib inline

# %%
# %sql sqlite:///demo.db3
# Out:
# 'Connected: @demo.db3'

# %%
# %sql select date('now');
# Out:
#  * sqlite:///demo.db3
# Done.
# [('2022-11-09',)]

# %%
# %sql select date('now', 'start of month', '+1 month', '-1 day');
# Out:
#  * sqlite:///demo.db3
# Done.
# [('2022-11-30',)]

# %%
# %%sql sqlite://
# DROP TABLE IF EXISTS Temperature;
# CREATE TABLE Temperature (Timestamp DATETIME NOT NULL, Temperature NUMERIC NOT NULL)
# Out:
# Done.
# Done.
# []

# %%
# %%sql sqlite://
# CREATE UNIQUE INDEX idx_timestamp ON Temperature (Timestamp);
# Out:
# Done.
# []

# %%
def dt(days):
  return timedelta(days=days)

N_rows = 500
now = datetime.now()

for i in range(N_rows):
  timestamp = now - dt(days=(N_rows - i))
  temperature = uniform(18, 26)
  # %sql INSERT INTO Temperature VALUES (:timestamp, :temperature);
# Out:
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.
#  * sqlite:///demo.db3
# 1 rows affected.

# %%
# %sql select datetime(Timestamp) as Date, Temperature FROM Temperature LIMIT 5
# Out:
#  * sqlite:///demo.db3
# Done.
# [('2021-06-27 13:25:09', 20.611932275558264),
#  ('2021-06-28 13:25:09', 24.548501454611447),
#  ('2021-06-29 13:25:09', 23.324485529470632),
#  ('2021-06-30 13:25:09', 21.502120855154914),
#  ('2021-07-01 13:25:09', 19.99465139068885)]

# %%
# %%sql sqlite://3
# SELECT Timestamp as Date, Temperature
# FROM Temperature
# Where Date<= '2022-06031 14:21:45'
# Out:
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys(['sqlite:///demo.db3'])
# Invalid SQLite URL: sqlite://3
# Valid SQLite URL forms are:
#  sqlite:///:memory: (or, sqlite://)
#  sqlite:///relative/path/to/file.db
#  sqlite:////absolute/path/to/file.db
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys(['sqlite:///demo.db3'])

# %%
# %%sql sqlite://
# SELECT Timestamp as Date, Temperature
# FROM Temperature
# WHERE CAST(striftime('%Y',Date) as Int) = 2021
# Out:
# (sqlite3.OperationalError) no such function: striftime
# [SQL: SELECT Timestamp as Date, Temperature
# FROM Temperature
# WHERE CAST(striftime('%Y',Date) as Int) = 2021]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# %%sql sqlite://
# SELECT strftime('%Y', Timestamp) as Year, AVG(Temperature) AS MEAN_TMP,
# MAX(Temperatur) AS MAX_TMP,
# MIN(Temperature) AS MIN_TMP
# FROM Temperature
# Group by strftime('%Y', Timestamp)
# Out:
# (sqlite3.OperationalError) no such column: Temperatur
# [SQL: SELECT strftime('%Y', Timestamp) as Year, AVG(Temperature) AS MEAN_TMP,
# MAX(Temperatur) AS MAX_TMP,
# MIN(Temperature) AS MIN_TMP
# FROM Temperature
# Group by strftime('%Y', Timestamp)]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
ts = %sql SELECT datetime(Timestamp) as date, Temperature FROM Temperature
df = ts.DataFrame()
df.set_index("date", inplace = True)
df.index = pd.to_datetime(df.index)
df.index
# Out:
#  * sqlite:///demo.db3
# Done.
# DatetimeIndex(['2021-06-27 13:25:09', '2021-06-28 13:25:09',
#                '2021-06-29 13:25:09', '2021-06-30 13:25:09',
#                '2021-07-01 13:25:09', '2021-07-02 13:25:09',
#                '2021-07-03 13:25:09', '2021-07-04 13:25:09',
#                '2021-07-05 13:25:09', '2021-07-06 13:25:09',
#                ...
#                '2022-10-30 13:25:09', '2022-10-31 13:25:09',
#                '2022-11-01 13:25:09', '2022-11-02 13:25:09',
#                '2022-11-03 13:25:09', '2022-11-04 13:25:09',
#                '2022-11-05 13:25:09', '2022-11-06 13:25:09',
#                '2022-11-07 13:25:09', '2022-11-08 13:25:09'],
#               dtype='datetime64[ns]', name='date', length=500, freq=None)

# %%
df.plot(figsize=(12,6))
